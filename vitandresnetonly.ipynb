# %%
"""ViT + CNN Fusion Network (Baseline 4)
ERBMAHE Dataset Classification
Binary Classification: Abnormal vs Normal

BASELINE 4 — ViT + CNN (No CBAM, No Quantum)

METHOD 2 K-FOLD WITH SEPARATE TEST SET:
- 10% holdout test set (never used during training)
- K-Fold cross-validation on remaining 90%
- Validation-based early stopping
- Best fold model evaluated on test set
"""

import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Import PyTorch & torchvision
try:
    import torch
    import torch.nn as nn
    import torch.nn.functional as F
    from torch.utils.data import Dataset, DataLoader
    from torchvision import transforms, models
    print("✓ PyTorch & torchvision imported successfully")
except Exception as e:
    print(f"❌ Error importing PyTorch/torchvision: {e}")
    sys.exit(1)

# Transformers (ViT)
try:
    from transformers import ViTImageProcessor, ViTModel
    print("✓ Transformers imported successfully")
except ImportError:
    print("📦 Installing Transformers...")
    import subprocess
    subprocess.check_call([sys.executable, "-m", "pip", "install", "transformers"])
    from transformers import ViTImageProcessor, ViTModel
    print("✓ Transformers installed successfully")

# Check GPU
if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. Please run this script on a machine with CUDA-enabled GPU and proper drivers.")
device = torch.device('cuda')
print(f"🔧 Using device: {device}")
print(f"🔧 PyTorch version: {torch.__version__}")

# Config
MODEL_NAME = "google/vit-base-patch16-224"
CLASSES = ['Abnormal', 'Normal']
N_FOLDS = 5

# ============================================================================
# CNN BRANCH (Plain ResNet18, No CBAM)
# ============================================================================
class CNN_Branch(nn.Module):
    def __init__(self, pretrained=True):
        super(CNN_Branch, self).__init__()
        resnet = models.resnet18(pretrained=pretrained)
        self.backbone = nn.Sequential(*list(resnet.children())[:-2])
        self.global_pool = nn.AdaptiveAvgPool2d(1)
    
    def forward(self, x):
        feat = self.backbone(x)
        feat = self.global_pool(feat)
        feat = feat.view(feat.size(0), -1)
        return feat

# ============================================================================
# Fusion Hybrid Model (ViT + CNN, No CBAM, No Quantum)
# ============================================================================
class ViTCNNFusion(nn.Module):
    def __init__(self, model_name, num_classes=2):
        super(ViTCNNFusion, self).__init__()
        self.vit = ViTModel.from_pretrained(model_name)
        vit_dim = self.vit.config.hidden_size  # 768
        cnn_dim = 512

        self.fusion_proj = nn.Linear(vit_dim + cnn_dim, vit_dim)
        self.cnn_branch = CNN_Branch(pretrained=True)

        self.classifier = nn.Sequential(
            nn.Linear(vit_dim, vit_dim // 2),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(vit_dim // 2, num_classes)
        )

    def forward(self, pixel_values):
        # ViT CLS token features
        vit_out = self.vit(pixel_values=pixel_values)
        vit_features = vit_out.last_hidden_state[:, 0]   # (B, 768)

        # CNN features
        cnn_features = self.cnn_branch(pixel_values)      # (B, 512)

        # Fuse
        fused = torch.cat([vit_features, cnn_features], dim=1)  # (B, 1280)
        fused = self.fusion_proj(fused)                          # (B, 768)

        logits = self.classifier(fused)
        return logits

# ============================================================================
# Focal Loss
# ============================================================================
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        p_t = torch.exp(-ce_loss)
        focal_loss = (1 - p_t) ** self.gamma * ce_loss
        if self.alpha is not None:
            if isinstance(self.alpha, (float, int)):
                alpha_t = self.alpha
            else:
                alpha_t = self.alpha[targets]
            focal_loss = alpha_t * focal_loss
        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# ============================================================================
# Early Stopping
# ============================================================================
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0, mode='max', verbose=True):
        self.patience = patience
        self.min_delta = min_delta
        self.mode = mode
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.best_epoch = 0

    def __call__(self, current_score, epoch):
        if self.best_score is None:
            self.best_score = current_score
            self.best_epoch = epoch
            if self.verbose:
                print(f"  ✓ Initial best score: {current_score:.4f}")
            return False
        if self.mode == 'max':
            improved = current_score > (self.best_score + self.min_delta)
        else:
            improved = current_score < (self.best_score - self.min_delta)
        if improved:
            self.best_score = current_score
            self.best_epoch = epoch
            self.counter = 0
            if self.verbose:
                print(f"  ✓ New best score: {current_score:.4f}")
        else:
            self.counter += 1
            if self.verbose:
                print(f"  No improvement. Patience: {self.counter}/{self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
                if self.verbose:
                    print(f"\n⚠️ Early stopping triggered!")
                    print(f"   Best score: {self.best_score:.4f} at epoch {self.best_epoch}")
        return self.early_stop

# ============================================================================
# DATASET
# ============================================================================
class ERBMAHEDataset(Dataset):
    def __init__(self, dataframe, processor, augment=False):
        self.df = dataframe.reset_index(drop=True)
        self.processor = processor
        self.augment = augment
        self.aug_transform = transforms.Compose([
            transforms.RandomRotation(10),
            transforms.RandomAffine(degrees=0, translate=(0.05, 0.05)),
            transforms.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.0),
            transforms.RandomHorizontalFlip(p=0.5),
        ])

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.loc[idx, 'image_path']
        label = self.df.loc[idx, 'class_id']
        image = Image.open(img_path).convert('RGB')
        if self.augment:
            image = self.aug_transform(image)
        inputs = self.processor(images=image, return_tensors="pt")
        pixel_values = inputs['pixel_values'].squeeze(0)
        return pixel_values, label

# ============================================================================
# TRAIN / VALIDATION FUNCTIONS
# ============================================================================

def train_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    pbar = tqdm(dataloader, desc='Training')
    for pixel_values, labels in pbar:
        pixel_values, labels = pixel_values.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = model(pixel_values)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = logits.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        pbar.set_postfix({
            'loss': f'{running_loss/(pbar.n+1):.4f}',
            'acc': f'{100.*correct/total:.2f}%'
        })
    _, _, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted', zero_division=0)
    return running_loss / len(dataloader), 100. * correct / total, f1


def validate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    all_preds = []
    all_labels = []
    with torch.no_grad():
        pbar = tqdm(dataloader, desc='Validation')
        for pixel_values, labels in pbar:
            pixel_values, labels = pixel_values.to(device), labels.to(device)
            logits = model(pixel_values)
            loss = criterion(logits, labels)
            running_loss += loss.item()
            _, predicted = logits.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            pbar.set_postfix({
                'loss': f'{running_loss/(pbar.n+1):.4f}',
                'acc': f'{100.*correct/total:.2f}%'
            })
    _, _, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='weighted', zero_division=0)
    return running_loss / len(dataloader), 100. * correct / total, f1, all_preds, all_labels


def calculate_metrics(y_true, y_pred):
    """Calculate comprehensive metrics including sensitivity and specificity"""
    cm = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = cm.ravel()

    sensitivity_class0 = tn / (tn + fn) if (tn + fn) > 0 else 0  # Normal
    sensitivity_class1 = tp / (tp + fp) if (tp + fp) > 0 else 0  # Abnormal

    specificity_class0 = tn / (tn + fp) if (tn + fp) > 0 else 0  # Normal
    specificity_class1 = tp / (tp + fn) if (tp + fn) > 0 else 0  # Abnormal

    avg_sensitivity = (sensitivity_class0 + sensitivity_class1) / 2
    avg_specificity = (specificity_class0 + specificity_class1) / 2

    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')
    accuracy = accuracy_score(y_true, y_pred)

    return {
        'accuracy': accuracy * 100,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'sensitivity_class0': sensitivity_class0,
        'sensitivity_class1': sensitivity_class1,
        'specificity_class0': specificity_class0,
        'specificity_class1': specificity_class1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        'confusion_matrix': cm
    }

# ============================================================================
# MAIN
# ============================================================================

def main():
    print("="*70)
    print("Baseline 4 — ViT + CNN Fusion Network (No CBAM, No Quantum)")
    print("ERBMAHE Dataset Classification")
    print("Binary Classification: Abnormal vs Normal")
    print(f"METHOD 2: K-FOLD ({N_FOLDS} folds) WITH SEPARATE TEST SET (10%)")
    print("="*70)

    data_path = 'D:/training/archive/ICMR_datasets_ERBMAHE'

    print(f"\n🤖 Base Model: {MODEL_NAME}")
    print(f"📊 Classes: {CLASSES}")
    print(f"🔄 K-Fold: {N_FOLDS} folds on 90% data")
    print(f"🧪 Test Set: 10% holdout")

    print("\n📁 Loading dataset...")
    data_list = []
    for class_name in CLASSES:
        class_path = os.path.join(data_path, class_name)
        if os.path.exists(class_path):
            for img_file in os.listdir(class_path):
                if img_file.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
                    data_list.append({
                        'image_path': os.path.join(class_path, img_file),
                        'label': class_name,
                        'class_id': CLASSES.index(class_name)
                    })
        else:
            print(f"⚠️ Warning: {class_path} not found!")

    df = pd.DataFrame(data_list)
    print(f"📊 Total images: {len(df)}")
    print("\nClass distribution:")
    print(df['label'].value_counts())

    # Split: 90% for k-fold, 10% for final test
    kfold_df, test_df = train_test_split(df, test_size=0.10, stratify=df['class_id'], random_state=42)

    print(f"\n📊 Dataset split:")
    print(f"  K-Fold data: {len(kfold_df)} ({len(kfold_df)/len(df)*100:.1f}%)")
    print(f"  Test data:   {len(test_df)} ({len(test_df)/len(df)*100:.1f}%)")

    # Class weights for focal loss
    class_counts = kfold_df['label'].value_counts().sort_index().values
    total_samples = len(kfold_df)
    class_weights = total_samples / (len(CLASSES) * class_counts)
    class_weights = torch.FloatTensor(class_weights).to(device)
    print(f"\n⚖️ Class weights for Focal Loss:")
    for i, class_name in enumerate(CLASSES):
        print(f"  {class_name}: {class_weights[i]:.4f}")

    # ViT processor
    print(f"\n🔧 Loading ViT processor...")
    processor = ViTImageProcessor.from_pretrained(MODEL_NAME)

    # K-Fold setup
    skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)

    fold_results = []
    all_fold_histories = []

    batch_size = 16
    num_epochs = 50

    print(f"\n⚙️ Training configuration:")
    print(f"  Max epochs per fold: {num_epochs}")
    print(f"  Batch size: {batch_size}")
    print(f"  Early stopping patience: 10 epochs")
    print(f"  Learning rate (ViT): 1e-5")
    print(f"  Learning rate (CNN): 2e-4")
    print(f"  Learning rate (Classifier): 1e-4")
    print(f"  Scheduler: CosineAnnealingLR")
    print(f"  Loss: Focal Loss (gamma=2.0)")
    print(f"  Strategy: Method 2 with separate test set")

    # ============================================================================
    # K-FOLD CROSS-VALIDATION
    # ============================================================================

    for fold_idx, (train_idx, val_idx) in enumerate(skf.split(kfold_df, kfold_df['class_id'])):
        print("\n" + "="*70)
        print(f"FOLD {fold_idx + 1}/{N_FOLDS}")
        print("="*70)

        train_df = kfold_df.iloc[train_idx].reset_index(drop=True)
        val_df = kfold_df.iloc[val_idx].reset_index(drop=True)

        print(f"\n📊 Fold {fold_idx + 1} split:")
        print(f"  Train:      {len(train_df)} ({len(train_df)/len(kfold_df)*100:.1f}% of k-fold data)")
        print(f"  Validation: {len(val_df)} ({len(val_df)/len(kfold_df)*100:.1f}% of k-fold data)")

        train_dataset = ERBMAHEDataset(train_df, processor=processor, augment=True)
        val_dataset = ERBMAHEDataset(val_df, processor=processor, augment=False)

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

        print(f"\n🤖 Creating model for Fold {fold_idx + 1}...")
        model = ViTCNNFusion(model_name=MODEL_NAME, num_classes=len(CLASSES)).to(device)

        for p in model.parameters():
            p.requires_grad = True

        if fold_idx == 0:
            total_params = sum(p.numel() for p in model.parameters())
            trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
            print(f"✓ Total parameters: {total_params:,}")
            print(f"✓ Trainable parameters: {trainable_params:,}")
            print(f"✓ Model size: {total_params * 4 / 1024 / 1024:.2f} MB")

        def build_optimizer(model):
            groups = []
            vit_params = [p for p in model.vit.parameters() if p.requires_grad]
            if vit_params:
                groups.append({'params': vit_params, 'lr': 1e-5})
            cnn_params = [p for p in model.cnn_branch.parameters() if p.requires_grad]
            if cnn_params:
                groups.append({'params': cnn_params, 'lr': 2e-4})
            clf_params = [p for p in model.classifier.parameters() if p.requires_grad]
            if clf_params:
                groups.append({'params': clf_params, 'lr': 1e-4})
            if not groups:
                groups = [{'params': [p for p in model.parameters() if p.requires_grad], 'lr': 1e-4}]
            return torch.optim.AdamW(groups, weight_decay=0.01)

        criterion = FocalLoss(alpha=class_weights, gamma=2.0, reduction='mean')
        optimizer = build_optimizer(model)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=1e-6)
        early_stopping = EarlyStopping(patience=10, min_delta=0.001, mode='max', verbose=True)

        best_val_acc = 0.0
        fold_history = {
            'train_loss': [], 'train_acc': [], 'train_f1': [],
            'val_loss': [], 'val_acc': [], 'val_f1': []
        }

        # Training loop
        for epoch in range(num_epochs):
            print(f"\nFold {fold_idx + 1} - Epoch {epoch+1}/{num_epochs}")
            print("-" * 70)

            train_loss, train_acc, train_f1 = train_epoch(model, train_loader, criterion, optimizer, device)
            val_loss, val_acc, val_f1, _, _ = validate(model, val_loader, criterion, device)

            scheduler.step()

            fold_history['train_loss'].append(train_loss)
            fold_history['train_acc'].append(train_acc)
            fold_history['train_f1'].append(train_f1)
            fold_history['val_loss'].append(val_loss)
            fold_history['val_acc'].append(val_acc)
            fold_history['val_f1'].append(val_f1)

            current_lr = optimizer.param_groups[0]['lr']
            print(f"\nResults:")
            print(f"  Train - Loss: {train_loss:.4f}, Acc: {train_acc:.2f}%, F1: {train_f1:.4f}")
            print(f"  Val   - Loss: {val_loss:.4f}, Acc: {val_acc:.2f}%, F1: {val_f1:.4f}")
            print(f"  Learning Rate (group0): {current_lr:.2e}")

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                torch.save(model.state_dict(), f'fold{fold_idx+1}_best.pth')
                print(f"  💾 Best model saved! (Val Acc: {best_val_acc:.2f}%)")

            if early_stopping(val_acc, epoch):
                print(f"\n⚠️ Early stopping at epoch {epoch+1}")
                break

        # Final validation evaluation
        print(f"\n📊 EVALUATING FOLD {fold_idx + 1}")
        print("="*70)
        model.load_state_dict(torch.load(f'fold{fold_idx+1}_best.pth'))
        val_loss, val_acc, val_f1, y_pred, y_true = validate(model, val_loader, criterion, device)

        metrics = calculate_metrics(y_true, y_pred)

        print(f"\n📈 Fold {fold_idx + 1} Validation Results:")
        print(f"  Accuracy:         {metrics['accuracy']:.2f}%")
        print(f"  Precision:        {metrics['precision']:.4f}")
        print(f"  Recall:           {metrics['recall']:.4f}")
        print(f"  F1 Score:         {metrics['f1']:.4f}")
        print(f"  Sensitivity (Normal):   {metrics['sensitivity_class0']:.4f}")
        print(f"  Sensitivity (Abnormal): {metrics['sensitivity_class1']:.4f}")
        print(f"  Specificity (Normal):   {metrics['specificity_class0']:.4f}")
        print(f"  Specificity (Abnormal): {metrics['specificity_class1']:.4f}")
        print(f"  Avg Sensitivity:  {metrics['avg_sensitivity']:.4f}")
        print(f"  Avg Specificity:  {metrics['avg_specificity']:.4f}")

        fold_results.append({
            'fold': fold_idx + 1,
            'val_acc': metrics['accuracy'],
            'val_precision': metrics['precision'],
            'val_recall': metrics['recall'],
            'val_f1': metrics['f1'],
            'val_sensitivity': metrics['avg_sensitivity'],
            'val_specificity': metrics['avg_specificity'],
            'best_val_acc': best_val_acc,
            'epochs_trained': len(fold_history['train_loss']),
            'model_path': f'fold{fold_idx+1}_best.pth',
            'y_true': y_true,
            'y_pred': y_pred,
            'metrics': metrics
        })

        all_fold_histories.append(fold_history)

        # Save confusion matrix
        cm = metrics['confusion_matrix']
        plt.figure(figsize=(8, 6))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES)
        plt.title(f'Fold {fold_idx + 1} - Confusion Matrix\n(Val Acc: {metrics["accuracy"]:.2f}%)')
        plt.ylabel('True Label')
        plt.xlabel('Predicted Label')
        plt.tight_layout()
        plt.savefig(f'fold{fold_idx+1}_confusion_matrix.png', dpi=150)
        plt.close()
        print(f"✓ Confusion matrix saved")

        # Enhanced visualizations for FIRST FOLD
        if fold_idx == 0:
            print(f"\n📊 Creating enhanced visualizations for Fold 1...")

            # 1. Training/Validation curves
            fig, axes = plt.subplots(1, 3, figsize=(18, 5))
            epochs_range = range(1, len(fold_history['train_loss']) + 1)

            axes[0].plot(epochs_range, fold_history['train_loss'], 'b-o', label='Train', linewidth=2, markersize=4)
            axes[0].plot(epochs_range, fold_history['val_loss'], 'r-s', label='Val', linewidth=2, markersize=4)
            axes[0].set_xlabel('Epoch', fontsize=12)
            axes[0].set_ylabel('Loss', fontsize=12)
            axes[0].set_title('Fold 1 - Loss', fontsize=14, fontweight='bold')
            axes[0].legend(fontsize=10)
            axes[0].grid(True, alpha=0.3)

            axes[1].plot(epochs_range, fold_history['train_acc'], 'b-o', label='Train', linewidth=2, markersize=4)
            axes[1].plot(epochs_range, fold_history['val_acc'], 'r-s', label='Val', linewidth=2, markersize=4)
            axes[1].set_xlabel('Epoch', fontsize=12)
            axes[1].set_ylabel('Accuracy (%)', fontsize=12)
            axes[1].set_title('Fold 1 - Accuracy', fontsize=14, fontweight='bold')
            axes[1].legend(fontsize=10)
            axes[1].grid(True, alpha=0.3)

            axes[2].plot(epochs_range, fold_history['train_f1'], 'b-o', label='Train', linewidth=2, markersize=4)
            axes[2].plot(epochs_range, fold_history['val_f1'], 'r-s', label='Val', linewidth=2, markersize=4)
            axes[2].set_xlabel('Epoch', fontsize=12)
            axes[2].set_ylabel('F1 Score', fontsize=12)
            axes[2].set_title('Fold 1 - F1 Score', fontsize=14, fontweight='bold')
            axes[2].legend(fontsize=10)
            axes[2].grid(True, alpha=0.3)

            plt.tight_layout()
            plt.savefig('fold1_training_curves.png', dpi=150)
            plt.close()
            print("  ✓ Training curves saved")

            # 2. Detailed confusion matrix
            fig, ax = plt.subplots(figsize=(10, 8))
            cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100
            annotations = np.empty_like(cm).astype(str)
            for i in range(cm.shape[0]):
                for j in range(cm.shape[1]):
                    annotations[i, j] = f'{cm[i, j]}\n({cm_percent[i, j]:.1f}%)'
            sns.heatmap(cm, annot=annotations, fmt='', cmap='Blues',
                       xticklabels=CLASSES, yticklabels=CLASSES,
                       cbar_kws={'label': 'Count'}, ax=ax)
            ax.set_title(f'Fold 1 - Detailed Confusion Matrix\nVal Acc: {metrics["accuracy"]:.2f}%',
                        fontsize=14, fontweight='bold')
            ax.set_ylabel('True Label', fontsize=12)
            ax.set_xlabel('Predicted Label', fontsize=12)
            plt.tight_layout()
            plt.savefig('fold1_confusion_detailed.png', dpi=150)
            plt.close()
            print("  ✓ Detailed confusion matrix saved")

            # 3. Metrics summary
            fig, ax = plt.subplots(figsize=(12, 6))
            metric_names = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'Sensitivity', 'Specificity']
            metric_values = [
                metrics['accuracy'],
                metrics['precision']*100,
                metrics['recall']*100,
                metrics['f1']*100,
                metrics['avg_sensitivity']*100,
                metrics['avg_specificity']*100
            ]
            colors = ['#3498db', '#2ecc71', '#e74c3c', '#f39c12', '#9b59b6', '#1abc9c']
            bars = ax.bar(metric_names, metric_values, color=colors, alpha=0.7, edgecolor='black', linewidth=1.5)
            for bar, value in zip(bars, metric_values):
                height = bar.get_height()
                ax.text(bar.get_x() + bar.get_width()/2., height,
                       f'{value:.2f}%', ha='center', va='bottom', fontsize=11, fontweight='bold')
            ax.set_ylabel('Score (%)', fontsize=12)
            ax.set_title('Fold 1 - Validation Metrics Summary', fontsize=14, fontweight='bold')
            ax.set_ylim([0, 105])
            ax.grid(True, alpha=0.3, axis='y')
            plt.xticks(rotation=15)
            plt.tight_layout()
            plt.savefig('fold1_metrics_summary.png', dpi=150)
            plt.close()
            print("  ✓ Metrics summary saved")

    # ============================================================================
    # SUMMARY ACROSS FOLDS
    # ============================================================================

    print("\n" + "="*70)
    print("📊 K-FOLD CROSS-VALIDATION SUMMARY")
    print("="*70)

    accuracies = [r['val_acc'] for r in fold_results]
    precisions = [r['val_precision'] for r in fold_results]
    recalls = [r['val_recall'] for r in fold_results]
    f1_scores = [r['val_f1'] for r in fold_results]
    sensitivities = [r['val_sensitivity'] for r in fold_results]
    specificities = [r['val_specificity'] for r in fold_results]

    print(f"\n📈 Cross-Validation Results ({N_FOLDS} folds):")
    print(f"  Accuracy:     {np.mean(accuracies):.2f}% ± {np.std(accuracies):.2f}%")
    print(f"  Precision:    {np.mean(precisions):.4f} ± {np.std(precisions):.4f}")
    print(f"  Recall:       {np.mean(recalls):.4f} ± {np.std(recalls):.4f}")
    print(f"  F1 Score:     {np.mean(f1_scores):.4f} ± {np.std(f1_scores):.4f}")
    print(f"  Sensitivity:  {np.mean(sensitivities):.4f} ± {np.std(sensitivities):.4f}")
    print(f"  Specificity:  {np.mean(specificities):.4f} ± {np.std(specificities):.4f}")

    # Find best fold
    best_fold_idx = np.argmax(accuracies)
    best_fold = fold_results[best_fold_idx]
    print(f"\n🏆 Best Fold: {best_fold['fold']} (Val Acc: {best_fold['val_acc']:.2f}%)")

    # ============================================================================
    # EVALUATE BEST MODEL ON TEST SET
    # ============================================================================

    print("\n" + "="*70)
    print("🧪 EVALUATING BEST MODEL ON HOLDOUT TEST SET")
    print("="*70)

    print(f"\n📊 Loading best model from Fold {best_fold['fold']}...")
    best_model = ViTCNNFusion(model_name=MODEL_NAME, num_classes=len(CLASSES)).to(device)
    best_model.load_state_dict(torch.load(best_fold['model_path']))

    test_dataset = ERBMAHEDataset(test_df, processor=processor, augment=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

    test_loss, test_acc, test_f1, test_pred, test_true = validate(best_model, test_loader, criterion, device)
    test_metrics = calculate_metrics(test_true, test_pred)

    print(f"\n📈 Test Set Results (Best Model from Fold {best_fold['fold']}):")
    print(f"  Accuracy:         {test_metrics['accuracy']:.2f}%")
    print(f"  Precision:        {test_metrics['precision']:.4f}")
    print(f"  Recall:           {test_metrics['recall']:.4f}")
    print(f"  F1 Score:         {test_metrics['f1']:.4f}")
    print(f"  Sensitivity (Normal):   {test_metrics['sensitivity_class0']:.4f}")
    print(f"  Sensitivity (Abnormal): {test_metrics['sensitivity_class1']:.4f}")
    print(f"  Specificity (Normal):   {test_metrics['specificity_class0']:.4f}")
    print(f"  Specificity (Abnormal): {test_metrics['specificity_class1']:.4f}")
    print(f"  Avg Sensitivity:  {test_metrics['avg_sensitivity']:.4f}")
    print(f"  Avg Specificity:  {test_metrics['avg_specificity']:.4f}")

    # Test confusion matrix
    test_cm = test_metrics['confusion_matrix']
    plt.figure(figsize=(10, 8))
    test_cm_percent = test_cm.astype('float') / test_cm.sum(axis=1)[:, np.newaxis] * 100
    test_annotations = np.empty_like(test_cm).astype(str)
    for i in range(test_cm.shape[0]):
        for j in range(test_cm.shape[1]):
            test_annotations[i, j] = f'{test_cm[i, j]}\n({test_cm_percent[i, j]:.1f}%)'
    sns.heatmap(test_cm, annot=test_annotations, fmt='', cmap='Greens',
               xticklabels=CLASSES, yticklabels=CLASSES,
               cbar_kws={'label': 'Count'})
    plt.title(f'Test Set Confusion Matrix\n(Best Model from Fold {best_fold["fold"]}, Acc: {test_metrics["accuracy"]:.2f}%)',
             fontsize=14, fontweight='bold')
    plt.ylabel('True Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('test_confusion_matrix.png', dpi=150)
    plt.close()
    print("\n✓ Test confusion matrix saved")

    # Save all results
    results_df = pd.DataFrame(fold_results)
    results_df.to_csv('kfold_results.csv', index=False)
    print("✓ Results saved to CSV")

    print("\n" + "="*70)
    print("✅ TRAINING COMPLETE")
    print("="*70)
    print(f"\n📊 Final Summary:")
    print(f"  Dataset: ERBMAHE (Abnormal vs Normal)")
    print(f"  Model: Baseline 4 — ViT + CNN (No CBAM, No Quantum)")
    print(f"  Strategy: Method 2 K-Fold with 10% Test Set")
    print(f"  K-Fold CV Accuracy: {np.mean(accuracies):.2f}% ± {np.std(accuracies):.2f}%")
    print(f"  Test Set Accuracy:  {test_metrics['accuracy']:.2f}%")
    print(f"  Test Set F1 Score:  {test_metrics['f1']:.4f}")
    print("\n" + "="*70)


if __name__ == '__main__':
    main()
# Out:
# ✓ PyTorch & torchvision imported successfully
# ✓ Transformers imported successfully
# 🔧 Using device: cuda
# 🔧 PyTorch version: 2.5.1+cu121
# ======================================================================
# Baseline 4 — ViT + CNN Fusion Network (No CBAM, No Quantum)
# ERBMAHE Dataset Classification
# Binary Classification: Abnormal vs Normal
# METHOD 2: K-FOLD (5 folds) WITH SEPARATE TEST SET (10%)
# ======================================================================
#
# 🤖 Base Model: google/vit-base-patch16-224
# 📊 Classes: ['Abnormal', 'Normal']
# 🔄 K-Fold: 5 folds on 90% data
# 🧪 Test Set: 10% holdout
#
# 📁 Loading dataset...
# 📊 Total images: 1981
#
# Class distribution:
# label
# Normal      1270
# Abnormal     711
# Name: count, dtype: int64
#
# 📊 Dataset split:
#   K-Fold data: 1782 (90.0%)
#   Test data:   199 (10.0%)
#
# ⚖️ Class weights for Focal Loss:
#   Abnormal: 1.3922
#   Normal: 0.7802
#
# 🔧 Loading ViT processor...
#
# ⚙️ Training configuration:
#   Max epochs per fold: 50
#   Batch size: 16
#   Early stopping patience: 10 epochs
#   Learning rate (ViT): 1e-5
#   Learning rate (CNN): 2e-4
#   Learning rate (Classifier): 1e-4
#   Scheduler: CosineAnnealingLR
#   Loss: Focal Loss (gamma=2.0)
#   Strategy: Method 2 with separate test set
#
# ======================================================================
# FOLD 1/5
# ======================================================================
#
# 📊 Fold 1 split:
#   Train:      1425 (80.0% of k-fold data)
#   Validation: 357 (20.0% of k-fold data)
#
# 🤖 Creating model for Fold 1...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ✓ Total parameters: 98,845,634
# ✓ Trainable parameters: 98,845,634
# ✓ Model size: 377.07 MB
#
# Fold 1 - Epoch 1/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:46<00:00,  4.51s/it, loss=0.0993, acc=83.09%]
# Validation: 100%|██████████| 23/23 [00:40<00:00,  1.76s/it, loss=0.0963, acc=84.31%]
# Results:
#   Train - Loss: 0.0993, Acc: 83.09%, F1: 0.8322
#   Val   - Loss: 0.0963, Acc: 84.31%, F1: 0.8463
#   Learning Rate (group0): 9.99e-06
#   💾 Best model saved! (Val Acc: 84.31%)
#   ✓ Initial best score: 84.3137
#
# Fold 1 - Epoch 2/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:47<00:00,  4.53s/it, loss=0.0698, acc=91.16%]
# Validation: 100%|██████████| 23/23 [00:39<00:00,  1.72s/it, loss=0.0508, acc=87.96%]
# Results:
#   Train - Loss: 0.0698, Acc: 91.16%, F1: 0.9120
#   Val   - Loss: 0.0508, Acc: 87.96%, F1: 0.8820
#   Learning Rate (group0): 9.96e-06
#   💾 Best model saved! (Val Acc: 87.96%)
#   ✓ New best score: 87.9552
#
# Fold 1 - Epoch 3/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:23<00:00,  4.26s/it, loss=0.0465, acc=92.98%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.65s/it, loss=0.0926, acc=84.87%]
# Results:
#   Train - Loss: 0.0465, Acc: 92.98%, F1: 0.9302
#   Val   - Loss: 0.0926, Acc: 84.87%, F1: 0.8518
#   Learning Rate (group0): 9.92e-06
#   No improvement. Patience: 1/10
#
# Fold 1 - Epoch 4/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.20s/it, loss=0.0500, acc=93.40%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.47s/it, loss=0.0382, acc=93.28%]
# Results:
#   Train - Loss: 0.0500, Acc: 93.40%, F1: 0.9344
#   Val   - Loss: 0.0382, Acc: 93.28%, F1: 0.9336
#   Learning Rate (group0): 9.86e-06
#   💾 Best model saved! (Val Acc: 93.28%)
#   ✓ New best score: 93.2773
#
# Fold 1 - Epoch 5/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:25<00:00,  4.28s/it, loss=0.0342, acc=94.95%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.65s/it, loss=0.0587, acc=94.68%]
# Results:
#   Train - Loss: 0.0342, Acc: 94.95%, F1: 0.9497
#   Val   - Loss: 0.0587, Acc: 94.68%, F1: 0.9458
#   Learning Rate (group0): 9.78e-06
#   💾 Best model saved! (Val Acc: 94.68%)
#   ✓ New best score: 94.6779
#
# Fold 1 - Epoch 6/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:24<00:00,  4.28s/it, loss=0.0343, acc=95.30%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.66s/it, loss=0.0291, acc=96.08%]
# Results:
#   Train - Loss: 0.0343, Acc: 95.30%, F1: 0.9532
#   Val   - Loss: 0.0291, Acc: 96.08%, F1: 0.9612
#   Learning Rate (group0): 9.68e-06
#   💾 Best model saved! (Val Acc: 96.08%)
#   ✓ New best score: 96.0784
#
# Fold 1 - Epoch 7/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:21<00:00,  4.24s/it, loss=0.0296, acc=95.93%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.59s/it, loss=0.0106, acc=98.88%]
# Results:
#   Train - Loss: 0.0296, Acc: 95.93%, F1: 0.9595
#   Val   - Loss: 0.0106, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 9.57e-06
#   💾 Best model saved! (Val Acc: 98.88%)
#   ✓ New best score: 98.8796
#
# Fold 1 - Epoch 8/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:21<00:00,  4.24s/it, loss=0.0202, acc=97.40%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.61s/it, loss=0.0356, acc=94.40%]
# Results:
#   Train - Loss: 0.0202, Acc: 97.40%, F1: 0.9741
#   Val   - Loss: 0.0356, Acc: 94.40%, F1: 0.9447
#   Learning Rate (group0): 9.44e-06
#   No improvement. Patience: 1/10
#
# Fold 1 - Epoch 9/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:20<00:00,  4.23s/it, loss=0.0179, acc=97.61%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.58s/it, loss=0.0183, acc=97.48%]
# Results:
#   Train - Loss: 0.0179, Acc: 97.61%, F1: 0.9762
#   Val   - Loss: 0.0183, Acc: 97.48%, F1: 0.9747
#   Learning Rate (group0): 9.30e-06
#   No improvement. Patience: 2/10
#
# Fold 1 - Epoch 10/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.19s/it, loss=0.0248, acc=97.33%]
# Validation: 100%|██████████| 23/23 [00:39<00:00,  1.70s/it, loss=0.0216, acc=97.20%]
# Results:
#   Train - Loss: 0.0248, Acc: 97.33%, F1: 0.9734
#   Val   - Loss: 0.0216, Acc: 97.20%, F1: 0.9722
#   Learning Rate (group0): 9.14e-06
#   No improvement. Patience: 3/10
#
# Fold 1 - Epoch 11/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:22<00:00,  4.25s/it, loss=0.0169, acc=97.54%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.61s/it, loss=0.0198, acc=97.48%]
# Results:
#   Train - Loss: 0.0169, Acc: 97.54%, F1: 0.9755
#   Val   - Loss: 0.0198, Acc: 97.48%, F1: 0.9749
#   Learning Rate (group0): 8.97e-06
#   No improvement. Patience: 4/10
#
# Fold 1 - Epoch 12/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:18<00:00,  4.21s/it, loss=0.0123, acc=98.46%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.65s/it, loss=0.0163, acc=98.88%]
# Results:
#   Train - Loss: 0.0123, Acc: 98.46%, F1: 0.9846
#   Val   - Loss: 0.0163, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 8.78e-06
#   No improvement. Patience: 5/10
#
# Fold 1 - Epoch 13/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:23<00:00,  4.26s/it, loss=0.0228, acc=97.47%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.62s/it, loss=0.0338, acc=97.76%]
# Results:
#   Train - Loss: 0.0228, Acc: 97.47%, F1: 0.9748
#   Val   - Loss: 0.0338, Acc: 97.76%, F1: 0.9777
#   Learning Rate (group0): 8.58e-06
#   No improvement. Patience: 6/10
#
# Fold 1 - Epoch 14/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:23<00:00,  4.26s/it, loss=0.0135, acc=98.04%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.63s/it, loss=0.0119, acc=98.88%]
# Results:
#   Train - Loss: 0.0135, Acc: 98.04%, F1: 0.9804
#   Val   - Loss: 0.0119, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 8.37e-06
#   No improvement. Patience: 7/10
#
# Fold 1 - Epoch 15/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:18<00:00,  4.21s/it, loss=0.0101, acc=98.88%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.65s/it, loss=0.0081, acc=98.32%]
# Results:
#   Train - Loss: 0.0101, Acc: 98.88%, F1: 0.9888
#   Val   - Loss: 0.0081, Acc: 98.32%, F1: 0.9832
#   Learning Rate (group0): 8.15e-06
#   No improvement. Patience: 8/10
#
# Fold 1 - Epoch 16/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.19s/it, loss=0.0068, acc=99.02%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.67s/it, loss=0.0311, acc=96.36%]
# Results:
#   Train - Loss: 0.0068, Acc: 99.02%, F1: 0.9902
#   Val   - Loss: 0.0311, Acc: 96.36%, F1: 0.9639
#   Learning Rate (group0): 7.91e-06
#   No improvement. Patience: 9/10
#
# Fold 1 - Epoch 17/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.19s/it, loss=0.0048, acc=99.37%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.60s/it, loss=0.0056, acc=98.60%]
# Results:
#   Train - Loss: 0.0048, Acc: 99.37%, F1: 0.9937
#   Val   - Loss: 0.0056, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 7.67e-06
#   No improvement. Patience: 10/10
#
# ⚠️ Early stopping triggered!
#    Best score: 98.8796 at epoch 6
#
# ⚠️ Early stopping at epoch 17
#
# 📊 EVALUATING FOLD 1
# ======================================================================
# Validation: 100%|██████████| 23/23 [00:34<00:00,  1.48s/it, loss=0.0106, acc=98.88%]
# 📈 Fold 1 Validation Results:
#   Accuracy:         98.88%
#   Precision:        0.9889
#   Recall:           0.9888
#   F1 Score:         0.9888
#   Sensitivity (Normal):   0.9769
#   Sensitivity (Abnormal): 0.9956
#   Specificity (Normal):   0.9922
#   Specificity (Abnormal): 0.9869
#   Avg Sensitivity:  0.9863
#   Avg Specificity:  0.9895
# ✓ Confusion matrix saved
#
# 📊 Creating enhanced visualizations for Fold 1...
#   ✓ Training curves saved
#   ✓ Detailed confusion matrix saved
#   ✓ Metrics summary saved
#
# ======================================================================
# FOLD 2/5
# ======================================================================
#
# 📊 Fold 2 split:
#   Train:      1425 (80.0% of k-fold data)
#   Validation: 357 (20.0% of k-fold data)
#
# 🤖 Creating model for Fold 2...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold 2 - Epoch 1/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:20<00:00,  4.23s/it, loss=0.1109, acc=80.84%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.64s/it, loss=0.1051, acc=84.87%]
# Results:
#   Train - Loss: 0.1109, Acc: 80.84%, F1: 0.8113
#   Val   - Loss: 0.1051, Acc: 84.87%, F1: 0.8378
#   Learning Rate (group0): 9.99e-06
#   💾 Best model saved! (Val Acc: 84.87%)
#   ✓ Initial best score: 84.8739
#
# Fold 2 - Epoch 2/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:22<00:00,  4.25s/it, loss=0.0741, acc=88.63%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.63s/it, loss=0.0535, acc=93.00%]
# Results:
#   Train - Loss: 0.0741, Acc: 88.63%, F1: 0.8870
#   Val   - Loss: 0.0535, Acc: 93.00%, F1: 0.9287
#   Learning Rate (group0): 9.96e-06
#   💾 Best model saved! (Val Acc: 93.00%)
#   ✓ New best score: 92.9972
#
# Fold 2 - Epoch 3/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:21<00:00,  4.24s/it, loss=0.0545, acc=90.81%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.66s/it, loss=0.0253, acc=96.64%]
# Results:
#   Train - Loss: 0.0545, Acc: 90.81%, F1: 0.9087
#   Val   - Loss: 0.0253, Acc: 96.64%, F1: 0.9665
#   Learning Rate (group0): 9.92e-06
#   💾 Best model saved! (Val Acc: 96.64%)
#   ✓ New best score: 96.6387
#
# Fold 2 - Epoch 4/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:20<00:00,  4.22s/it, loss=0.0353, acc=94.60%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.67s/it, loss=0.0244, acc=94.40%]
# Results:
#   Train - Loss: 0.0353, Acc: 94.60%, F1: 0.9462
#   Val   - Loss: 0.0244, Acc: 94.40%, F1: 0.9445
#   Learning Rate (group0): 9.86e-06
#   No improvement. Patience: 1/10
#
# Fold 2 - Epoch 5/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:20<00:00,  4.23s/it, loss=0.0404, acc=94.95%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.68s/it, loss=0.0329, acc=93.28%]
# Results:
#   Train - Loss: 0.0404, Acc: 94.95%, F1: 0.9497
#   Val   - Loss: 0.0329, Acc: 93.28%, F1: 0.9338
#   Learning Rate (group0): 9.78e-06
#   No improvement. Patience: 2/10
#
# Fold 2 - Epoch 6/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:21<00:00,  4.24s/it, loss=0.0269, acc=95.58%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.65s/it, loss=0.0179, acc=98.60%]
# Results:
#   Train - Loss: 0.0269, Acc: 95.58%, F1: 0.9560
#   Val   - Loss: 0.0179, Acc: 98.60%, F1: 0.9859
#   Learning Rate (group0): 9.68e-06
#   💾 Best model saved! (Val Acc: 98.60%)
#   ✓ New best score: 98.5994
#
# Fold 2 - Epoch 7/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:20<00:00,  4.23s/it, loss=0.0183, acc=97.54%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.61s/it, loss=0.0762, acc=96.64%]
# Results:
#   Train - Loss: 0.0183, Acc: 97.54%, F1: 0.9755
#   Val   - Loss: 0.0762, Acc: 96.64%, F1: 0.9660
#   Learning Rate (group0): 9.57e-06
#   No improvement. Patience: 1/10
#
# Fold 2 - Epoch 8/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.19s/it, loss=0.0306, acc=96.35%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.56s/it, loss=0.0129, acc=97.48%]
# Results:
#   Train - Loss: 0.0306, Acc: 96.35%, F1: 0.9636
#   Val   - Loss: 0.0129, Acc: 97.48%, F1: 0.9750
#   Learning Rate (group0): 9.44e-06
#   No improvement. Patience: 2/10
#
# Fold 2 - Epoch 9/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:26<00:00,  4.30s/it, loss=0.0302, acc=94.67%]
# Validation: 100%|██████████| 23/23 [00:40<00:00,  1.78s/it, loss=0.0087, acc=98.60%]
# Results:
#   Train - Loss: 0.0302, Acc: 94.67%, F1: 0.9470
#   Val   - Loss: 0.0087, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 9.30e-06
#   No improvement. Patience: 3/10
#
# Fold 2 - Epoch 10/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:31<00:00,  4.35s/it, loss=0.0264, acc=96.35%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.68s/it, loss=0.0669, acc=96.08%]
# Results:
#   Train - Loss: 0.0264, Acc: 96.35%, F1: 0.9637
#   Val   - Loss: 0.0669, Acc: 96.08%, F1: 0.9603
#   Learning Rate (group0): 9.14e-06
#   No improvement. Patience: 4/10
#
# Fold 2 - Epoch 11/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:25<00:00,  4.28s/it, loss=0.0144, acc=98.11%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.47s/it, loss=0.0219, acc=96.64%]
# Results:
#   Train - Loss: 0.0144, Acc: 98.11%, F1: 0.9811
#   Val   - Loss: 0.0219, Acc: 96.64%, F1: 0.9666
#   Learning Rate (group0): 8.97e-06
#   No improvement. Patience: 5/10
#
# Fold 2 - Epoch 12/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:25<00:00,  4.28s/it, loss=0.0089, acc=98.81%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.48s/it, loss=0.0031, acc=99.44%]
# Results:
#   Train - Loss: 0.0089, Acc: 98.81%, F1: 0.9881
#   Val   - Loss: 0.0031, Acc: 99.44%, F1: 0.9944
#   Learning Rate (group0): 8.78e-06
#   💾 Best model saved! (Val Acc: 99.44%)
#   ✓ New best score: 99.4398
#
# Fold 2 - Epoch 13/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:24<00:00,  4.28s/it, loss=0.0100, acc=98.74%]
# Validation: 100%|██████████| 23/23 [00:41<00:00,  1.82s/it, loss=0.0103, acc=98.60%]
# Results:
#   Train - Loss: 0.0100, Acc: 98.74%, F1: 0.9874
#   Val   - Loss: 0.0103, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 8.58e-06
#   No improvement. Patience: 1/10
#
# Fold 2 - Epoch 14/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:40<00:00,  3.78s/it, loss=0.0117, acc=98.81%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0337, acc=94.68%]
# Results:
#   Train - Loss: 0.0117, Acc: 98.81%, F1: 0.9881
#   Val   - Loss: 0.0337, Acc: 94.68%, F1: 0.9475
#   Learning Rate (group0): 8.37e-06
#   No improvement. Patience: 2/10
#
# Fold 2 - Epoch 15/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:15<00:00,  3.51s/it, loss=0.0138, acc=98.04%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.32s/it, loss=0.0126, acc=98.04%]
# Results:
#   Train - Loss: 0.0138, Acc: 98.04%, F1: 0.9804
#   Val   - Loss: 0.0126, Acc: 98.04%, F1: 0.9805
#   Learning Rate (group0): 8.15e-06
#   No improvement. Patience: 3/10
#
# Fold 2 - Epoch 16/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:12<00:00,  3.47s/it, loss=0.0185, acc=97.54%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0094, acc=98.88%]
# Results:
#   Train - Loss: 0.0185, Acc: 97.54%, F1: 0.9755
#   Val   - Loss: 0.0094, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 7.91e-06
#   No improvement. Patience: 4/10
#
# Fold 2 - Epoch 17/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.49s/it, loss=0.0140, acc=98.25%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0114, acc=97.76%]
# Results:
#   Train - Loss: 0.0140, Acc: 98.25%, F1: 0.9825
#   Val   - Loss: 0.0114, Acc: 97.76%, F1: 0.9777
#   Learning Rate (group0): 7.67e-06
#   No improvement. Patience: 5/10
#
# Fold 2 - Epoch 18/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.49s/it, loss=0.0082, acc=99.37%]
# Validation: 100%|██████████| 23/23 [00:29<00:00,  1.27s/it, loss=0.0062, acc=99.16%]
# Results:
#   Train - Loss: 0.0082, Acc: 99.37%, F1: 0.9937
#   Val   - Loss: 0.0062, Acc: 99.16%, F1: 0.9916
#   Learning Rate (group0): 7.42e-06
#   No improvement. Patience: 6/10
#
# Fold 2 - Epoch 19/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [04:56<00:00,  3.29s/it, loss=0.0153, acc=97.54%]
# Validation: 100%|██████████| 23/23 [00:29<00:00,  1.28s/it, loss=0.0144, acc=96.36%]
# Results:
#   Train - Loss: 0.0153, Acc: 97.54%, F1: 0.9755
#   Val   - Loss: 0.0144, Acc: 96.36%, F1: 0.9639
#   Learning Rate (group0): 7.16e-06
#   No improvement. Patience: 7/10
#
# Fold 2 - Epoch 20/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0034, acc=99.72%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.34s/it, loss=0.0031, acc=99.44%]
# Results:
#   Train - Loss: 0.0034, Acc: 99.72%, F1: 0.9972
#   Val   - Loss: 0.0031, Acc: 99.44%, F1: 0.9944
#   Learning Rate (group0): 6.89e-06
#   No improvement. Patience: 8/10
#
# Fold 2 - Epoch 21/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:09<00:00,  3.44s/it, loss=0.0066, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.39s/it, loss=0.0060, acc=99.44%]
# Results:
#   Train - Loss: 0.0066, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0060, Acc: 99.44%, F1: 0.9944
#   Learning Rate (group0): 6.62e-06
#   No improvement. Patience: 9/10
#
# Fold 2 - Epoch 22/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0058, acc=99.58%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.36s/it, loss=0.0036, acc=99.44%]
# Results:
#   Train - Loss: 0.0058, Acc: 99.58%, F1: 0.9958
#   Val   - Loss: 0.0036, Acc: 99.44%, F1: 0.9944
#   Learning Rate (group0): 6.34e-06
#   No improvement. Patience: 10/10
#
# ⚠️ Early stopping triggered!
#    Best score: 99.4398 at epoch 11
#
# ⚠️ Early stopping at epoch 22
#
# 📊 EVALUATING FOLD 2
# ======================================================================
# Validation: 100%|██████████| 23/23 [00:26<00:00,  1.17s/it, loss=0.0031, acc=99.44%]
# 📈 Fold 2 Validation Results:
#   Accuracy:         99.44%
#   Precision:        0.9944
#   Recall:           0.9944
#   F1 Score:         0.9944
#   Sensitivity (Normal):   1.0000
#   Sensitivity (Abnormal): 0.9913
#   Specificity (Normal):   0.9844
#   Specificity (Abnormal): 1.0000
#   Avg Sensitivity:  0.9957
#   Avg Specificity:  0.9922
# ✓ Confusion matrix saved
#
# ======================================================================
# FOLD 3/5
# ======================================================================
#
# 📊 Fold 3 split:
#   Train:      1426 (80.0% of k-fold data)
#   Validation: 356 (20.0% of k-fold data)
#
# 🤖 Creating model for Fold 3...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold 3 - Epoch 1/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:09<00:00,  3.44s/it, loss=0.1052, acc=80.29%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0598, acc=90.45%]
# Results:
#   Train - Loss: 0.1052, Acc: 80.29%, F1: 0.8052
#   Val   - Loss: 0.0598, Acc: 90.45%, F1: 0.9038
#   Learning Rate (group0): 9.99e-06
#   💾 Best model saved! (Val Acc: 90.45%)
#   ✓ Initial best score: 90.4494
#
# Fold 3 - Epoch 2/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:09<00:00,  3.44s/it, loss=0.0592, acc=91.80%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.33s/it, loss=0.0355, acc=94.94%]
# Results:
#   Train - Loss: 0.0592, Acc: 91.80%, F1: 0.9184
#   Val   - Loss: 0.0355, Acc: 94.94%, F1: 0.9495
#   Learning Rate (group0): 9.96e-06
#   💾 Best model saved! (Val Acc: 94.94%)
#   ✓ New best score: 94.9438
#
# Fold 3 - Epoch 3/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:06<00:00,  3.40s/it, loss=0.0493, acc=93.27%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.40s/it, loss=0.0417, acc=94.38%]
# Results:
#   Train - Loss: 0.0493, Acc: 93.27%, F1: 0.9330
#   Val   - Loss: 0.0417, Acc: 94.38%, F1: 0.9442
#   Learning Rate (group0): 9.92e-06
#   No improvement. Patience: 1/10
#
# Fold 3 - Epoch 4/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:00<00:00,  3.34s/it, loss=0.0426, acc=95.44%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.33s/it, loss=0.0876, acc=89.04%]
# Results:
#   Train - Loss: 0.0426, Acc: 95.44%, F1: 0.9545
#   Val   - Loss: 0.0876, Acc: 89.04%, F1: 0.8917
#   Learning Rate (group0): 9.86e-06
#   No improvement. Patience: 2/10
#
# Fold 3 - Epoch 5/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:06<00:00,  3.40s/it, loss=0.0362, acc=95.30%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.40s/it, loss=0.0454, acc=93.26%]
# Results:
#   Train - Loss: 0.0362, Acc: 95.30%, F1: 0.9532
#   Val   - Loss: 0.0454, Acc: 93.26%, F1: 0.9334
#   Learning Rate (group0): 9.78e-06
#   No improvement. Patience: 3/10
#
# Fold 3 - Epoch 6/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.49s/it, loss=0.0434, acc=95.58%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0250, acc=96.35%]
# Results:
#   Train - Loss: 0.0434, Acc: 95.58%, F1: 0.9559
#   Val   - Loss: 0.0250, Acc: 96.35%, F1: 0.9636
#   Learning Rate (group0): 9.68e-06
#   💾 Best model saved! (Val Acc: 96.35%)
#   ✓ New best score: 96.3483
#
# Fold 3 - Epoch 7/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.48s/it, loss=0.0348, acc=94.81%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0616, acc=91.57%]
# Results:
#   Train - Loss: 0.0348, Acc: 94.81%, F1: 0.9484
#   Val   - Loss: 0.0616, Acc: 91.57%, F1: 0.9172
#   Learning Rate (group0): 9.57e-06
#   No improvement. Patience: 1/10
#
# Fold 3 - Epoch 8/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0195, acc=97.62%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.41s/it, loss=0.0269, acc=96.07%]
# Results:
#   Train - Loss: 0.0195, Acc: 97.62%, F1: 0.9762
#   Val   - Loss: 0.0269, Acc: 96.07%, F1: 0.9604
#   Learning Rate (group0): 9.44e-06
#   No improvement. Patience: 2/10
#
# Fold 3 - Epoch 9/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:14<00:00,  3.49s/it, loss=0.0152, acc=98.32%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.41s/it, loss=0.0109, acc=98.88%]
# Results:
#   Train - Loss: 0.0152, Acc: 98.32%, F1: 0.9832
#   Val   - Loss: 0.0109, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 9.30e-06
#   💾 Best model saved! (Val Acc: 98.88%)
#   ✓ New best score: 98.8764
#
# Fold 3 - Epoch 10/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:17<00:00,  3.53s/it, loss=0.0145, acc=97.62%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0137, acc=98.60%]
# Results:
#   Train - Loss: 0.0145, Acc: 97.62%, F1: 0.9762
#   Val   - Loss: 0.0137, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 9.14e-06
#   No improvement. Patience: 1/10
#
# Fold 3 - Epoch 11/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:15<00:00,  3.51s/it, loss=0.0205, acc=97.83%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0411, acc=96.63%]
# Results:
#   Train - Loss: 0.0205, Acc: 97.83%, F1: 0.9783
#   Val   - Loss: 0.0411, Acc: 96.63%, F1: 0.9659
#   Learning Rate (group0): 8.97e-06
#   No improvement. Patience: 2/10
#
# Fold 3 - Epoch 12/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:00<00:00,  3.34s/it, loss=0.0282, acc=97.48%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.35s/it, loss=0.0333, acc=94.94%]
# Results:
#   Train - Loss: 0.0282, Acc: 97.48%, F1: 0.9748
#   Val   - Loss: 0.0333, Acc: 94.94%, F1: 0.9500
#   Learning Rate (group0): 8.78e-06
#   No improvement. Patience: 3/10
#
# Fold 3 - Epoch 13/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:02<00:00,  3.36s/it, loss=0.0232, acc=96.91%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.32s/it, loss=0.0155, acc=98.31%]
# Results:
#   Train - Loss: 0.0232, Acc: 96.91%, F1: 0.9693
#   Val   - Loss: 0.0155, Acc: 98.31%, F1: 0.9832
#   Learning Rate (group0): 8.58e-06
#   No improvement. Patience: 4/10
#
# Fold 3 - Epoch 14/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:06<00:00,  3.40s/it, loss=0.0186, acc=97.12%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.34s/it, loss=0.0091, acc=98.31%]
# Results:
#   Train - Loss: 0.0186, Acc: 97.12%, F1: 0.9713
#   Val   - Loss: 0.0091, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 8.37e-06
#   No improvement. Patience: 5/10
#
# Fold 3 - Epoch 15/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:07<00:00,  3.42s/it, loss=0.0092, acc=98.39%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.34s/it, loss=0.0268, acc=97.47%]
# Results:
#   Train - Loss: 0.0092, Acc: 98.39%, F1: 0.9839
#   Val   - Loss: 0.0268, Acc: 97.47%, F1: 0.9746
#   Learning Rate (group0): 8.15e-06
#   No improvement. Patience: 6/10
#
# Fold 3 - Epoch 16/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:05<00:00,  3.40s/it, loss=0.0071, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.36s/it, loss=0.0348, acc=95.51%]
# Results:
#   Train - Loss: 0.0071, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0348, Acc: 95.51%, F1: 0.9555
#   Learning Rate (group0): 7.91e-06
#   No improvement. Patience: 7/10
#
# Fold 3 - Epoch 17/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:09<00:00,  3.43s/it, loss=0.0145, acc=98.25%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.35s/it, loss=0.0053, acc=99.16%]
# Results:
#   Train - Loss: 0.0145, Acc: 98.25%, F1: 0.9825
#   Val   - Loss: 0.0053, Acc: 99.16%, F1: 0.9916
#   Learning Rate (group0): 7.67e-06
#   💾 Best model saved! (Val Acc: 99.16%)
#   ✓ New best score: 99.1573
#
# Fold 3 - Epoch 18/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:07<00:00,  3.41s/it, loss=0.0110, acc=98.39%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.39s/it, loss=0.0506, acc=94.94%]
# Results:
#   Train - Loss: 0.0110, Acc: 98.39%, F1: 0.9839
#   Val   - Loss: 0.0506, Acc: 94.94%, F1: 0.9499
#   Learning Rate (group0): 7.42e-06
#   No improvement. Patience: 1/10
#
# Fold 3 - Epoch 19/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:18<00:00,  4.21s/it, loss=0.0075, acc=99.30%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.62s/it, loss=0.0151, acc=98.03%]
# Results:
#   Train - Loss: 0.0075, Acc: 99.30%, F1: 0.9930
#   Val   - Loss: 0.0151, Acc: 98.03%, F1: 0.9804
#   Learning Rate (group0): 7.16e-06
#   No improvement. Patience: 2/10
#
# Fold 3 - Epoch 20/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:22<00:00,  4.25s/it, loss=0.0028, acc=99.65%]
# Validation: 100%|██████████| 23/23 [00:34<00:00,  1.48s/it, loss=0.0073, acc=99.16%]
# Results:
#   Train - Loss: 0.0028, Acc: 99.65%, F1: 0.9965
#   Val   - Loss: 0.0073, Acc: 99.16%, F1: 0.9916
#   Learning Rate (group0): 6.89e-06
#   No improvement. Patience: 3/10
#
# Fold 3 - Epoch 21/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:09<00:00,  4.11s/it, loss=0.0041, acc=99.65%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0157, acc=98.88%]
# Results:
#   Train - Loss: 0.0041, Acc: 99.65%, F1: 0.9965
#   Val   - Loss: 0.0157, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 6.62e-06
#   No improvement. Patience: 4/10
#
# Fold 3 - Epoch 22/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:08<00:00,  4.10s/it, loss=0.0049, acc=99.58%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.47s/it, loss=0.0083, acc=99.16%]
# Results:
#   Train - Loss: 0.0049, Acc: 99.58%, F1: 0.9958
#   Val   - Loss: 0.0083, Acc: 99.16%, F1: 0.9916
#   Learning Rate (group0): 6.34e-06
#   No improvement. Patience: 5/10
#
# Fold 3 - Epoch 23/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:11<00:00,  4.12s/it, loss=0.0033, acc=99.58%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0086, acc=98.88%]
# Results:
#   Train - Loss: 0.0033, Acc: 99.58%, F1: 0.9958
#   Val   - Loss: 0.0086, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 6.06e-06
#   No improvement. Patience: 6/10
#
# Fold 3 - Epoch 24/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:08<00:00,  4.09s/it, loss=0.0092, acc=99.72%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.48s/it, loss=0.0139, acc=98.31%]
# Results:
#   Train - Loss: 0.0092, Acc: 99.72%, F1: 0.9972
#   Val   - Loss: 0.0139, Acc: 98.31%, F1: 0.9832
#   Learning Rate (group0): 5.78e-06
#   No improvement. Patience: 7/10
#
# Fold 3 - Epoch 25/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:08<00:00,  4.10s/it, loss=0.0184, acc=98.11%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0330, acc=97.75%]
# Results:
#   Train - Loss: 0.0184, Acc: 98.11%, F1: 0.9811
#   Val   - Loss: 0.0330, Acc: 97.75%, F1: 0.9774
#   Learning Rate (group0): 5.50e-06
#   No improvement. Patience: 8/10
#
# Fold 3 - Epoch 26/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:08<00:00,  4.09s/it, loss=0.0089, acc=98.81%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.47s/it, loss=0.0131, acc=98.88%]
# Results:
#   Train - Loss: 0.0089, Acc: 98.81%, F1: 0.9881
#   Val   - Loss: 0.0131, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 5.22e-06
#   No improvement. Patience: 9/10
#
# Fold 3 - Epoch 27/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:09<00:00,  4.11s/it, loss=0.0057, acc=99.09%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0154, acc=98.03%]
# Results:
#   Train - Loss: 0.0057, Acc: 99.09%, F1: 0.9909
#   Val   - Loss: 0.0154, Acc: 98.03%, F1: 0.9802
#   Learning Rate (group0): 4.94e-06
#   No improvement. Patience: 10/10
#
# ⚠️ Early stopping triggered!
#    Best score: 99.1573 at epoch 16
#
# ⚠️ Early stopping at epoch 27
#
# 📊 EVALUATING FOLD 3
# ======================================================================
# Validation: 100%|██████████| 23/23 [00:34<00:00,  1.48s/it, loss=0.0053, acc=99.16%]
# 📈 Fold 3 Validation Results:
#   Accuracy:         99.16%
#   Precision:        0.9916
#   Recall:           0.9916
#   F1 Score:         0.9916
#   Sensitivity (Normal):   0.9845
#   Sensitivity (Abnormal): 0.9956
#   Specificity (Normal):   0.9922
#   Specificity (Abnormal): 0.9912
#   Avg Sensitivity:  0.9900
#   Avg Specificity:  0.9917
# ✓ Confusion matrix saved
#
# ======================================================================
# FOLD 4/5
# ======================================================================
#
# 📊 Fold 4 split:
#   Train:      1426 (80.0% of k-fold data)
#   Validation: 356 (20.0% of k-fold data)
#
# 🤖 Creating model for Fold 4...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold 4 - Epoch 1/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:09<00:00,  4.10s/it, loss=0.1030, acc=82.40%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.45s/it, loss=0.0473, acc=92.98%]
# Results:
#   Train - Loss: 0.1030, Acc: 82.40%, F1: 0.8264
#   Val   - Loss: 0.0473, Acc: 92.98%, F1: 0.9306
#   Learning Rate (group0): 9.99e-06
#   💾 Best model saved! (Val Acc: 92.98%)
#   ✓ Initial best score: 92.9775
#
# Fold 4 - Epoch 2/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:11<00:00,  4.12s/it, loss=0.0622, acc=91.51%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.45s/it, loss=0.1652, acc=69.66%]
# Results:
#   Train - Loss: 0.0622, Acc: 91.51%, F1: 0.9157
#   Val   - Loss: 0.1652, Acc: 69.66%, F1: 0.6951
#   Learning Rate (group0): 9.96e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 3/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:10<00:00,  4.12s/it, loss=0.0512, acc=92.92%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.45s/it, loss=0.0805, acc=87.64%]
# Results:
#   Train - Loss: 0.0512, Acc: 92.92%, F1: 0.9294
#   Val   - Loss: 0.0805, Acc: 87.64%, F1: 0.8788
#   Learning Rate (group0): 9.92e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 4/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:10<00:00,  4.11s/it, loss=0.0439, acc=93.90%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0703, acc=93.82%]
# Results:
#   Train - Loss: 0.0439, Acc: 93.90%, F1: 0.9393
#   Val   - Loss: 0.0703, Acc: 93.82%, F1: 0.9370
#   Learning Rate (group0): 9.86e-06
#   💾 Best model saved! (Val Acc: 93.82%)
#   ✓ New best score: 93.8202
#
# Fold 4 - Epoch 5/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:26<00:00,  4.30s/it, loss=0.0259, acc=96.84%]
# Validation: 100%|██████████| 23/23 [00:43<00:00,  1.89s/it, loss=0.1190, acc=78.65%]
# Results:
#   Train - Loss: 0.0259, Acc: 96.84%, F1: 0.9685
#   Val   - Loss: 0.1190, Acc: 78.65%, F1: 0.7896
#   Learning Rate (group0): 9.78e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 6/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:23<00:00,  4.93s/it, loss=0.0358, acc=95.09%]
# Validation: 100%|██████████| 23/23 [00:39<00:00,  1.72s/it, loss=0.0595, acc=89.33%]
# Results:
#   Train - Loss: 0.0358, Acc: 95.09%, F1: 0.9512
#   Val   - Loss: 0.0595, Acc: 89.33%, F1: 0.8953
#   Learning Rate (group0): 9.68e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 7/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:29<00:00,  4.99s/it, loss=0.0209, acc=96.70%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.69s/it, loss=0.0196, acc=96.63%]
# Results:
#   Train - Loss: 0.0209, Acc: 96.70%, F1: 0.9671
#   Val   - Loss: 0.0196, Acc: 96.63%, F1: 0.9665
#   Learning Rate (group0): 9.57e-06
#   💾 Best model saved! (Val Acc: 96.63%)
#   ✓ New best score: 96.6292
#
# Fold 4 - Epoch 8/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:31<00:00,  5.01s/it, loss=0.0352, acc=96.35%]
# Validation: 100%|██████████| 23/23 [00:38<00:00,  1.69s/it, loss=0.0325, acc=94.10%]
# Results:
#   Train - Loss: 0.0352, Acc: 96.35%, F1: 0.9637
#   Val   - Loss: 0.0325, Acc: 94.10%, F1: 0.9418
#   Learning Rate (group0): 9.44e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 9/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:50<00:00,  4.57s/it, loss=0.0243, acc=96.28%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.58s/it, loss=0.0850, acc=84.55%]
# Results:
#   Train - Loss: 0.0243, Acc: 96.28%, F1: 0.9629
#   Val   - Loss: 0.0850, Acc: 84.55%, F1: 0.8486
#   Learning Rate (group0): 9.30e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 10/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:45<00:00,  4.51s/it, loss=0.0356, acc=94.95%]
# Validation: 100%|██████████| 23/23 [00:41<00:00,  1.79s/it, loss=0.0301, acc=94.38%]
# Results:
#   Train - Loss: 0.0356, Acc: 94.95%, F1: 0.9498
#   Val   - Loss: 0.0301, Acc: 94.38%, F1: 0.9446
#   Learning Rate (group0): 9.14e-06
#   No improvement. Patience: 3/10
#
# Fold 4 - Epoch 11/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:31<00:00,  4.35s/it, loss=0.0223, acc=97.48%]
# Validation: 100%|██████████| 23/23 [00:34<00:00,  1.50s/it, loss=0.0251, acc=96.63%]
# Results:
#   Train - Loss: 0.0223, Acc: 97.48%, F1: 0.9749
#   Val   - Loss: 0.0251, Acc: 96.63%, F1: 0.9665
#   Learning Rate (group0): 8.97e-06
#   No improvement. Patience: 4/10
#
# Fold 4 - Epoch 12/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:22<00:00,  4.25s/it, loss=0.0214, acc=97.41%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.52s/it, loss=0.0443, acc=95.22%]
# Results:
#   Train - Loss: 0.0214, Acc: 97.41%, F1: 0.9741
#   Val   - Loss: 0.0443, Acc: 95.22%, F1: 0.9515
#   Learning Rate (group0): 8.78e-06
#   No improvement. Patience: 5/10
#
# Fold 4 - Epoch 13/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:26<00:00,  4.29s/it, loss=0.0144, acc=98.11%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.53s/it, loss=0.0144, acc=96.91%]
# Results:
#   Train - Loss: 0.0144, Acc: 98.11%, F1: 0.9811
#   Val   - Loss: 0.0144, Acc: 96.91%, F1: 0.9692
#   Learning Rate (group0): 8.58e-06
#   💾 Best model saved! (Val Acc: 96.91%)
#   ✓ New best score: 96.9101
#
# Fold 4 - Epoch 14/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:05<00:00,  4.06s/it, loss=0.0058, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:34<00:00,  1.49s/it, loss=0.0157, acc=97.19%]
# Results:
#   Train - Loss: 0.0058, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0157, Acc: 97.19%, F1: 0.9721
#   Learning Rate (group0): 8.37e-06
#   💾 Best model saved! (Val Acc: 97.19%)
#   ✓ New best score: 97.1910
#
# Fold 4 - Epoch 15/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:02<00:00,  4.03s/it, loss=0.0095, acc=98.60%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.41s/it, loss=0.0107, acc=98.03%]
# Results:
#   Train - Loss: 0.0095, Acc: 98.60%, F1: 0.9860
#   Val   - Loss: 0.0107, Acc: 98.03%, F1: 0.9803
#   Learning Rate (group0): 8.15e-06
#   💾 Best model saved! (Val Acc: 98.03%)
#   ✓ New best score: 98.0337
#
# Fold 4 - Epoch 16/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:59<00:00,  3.99s/it, loss=0.0043, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.41s/it, loss=0.0087, acc=97.75%]
# Results:
#   Train - Loss: 0.0043, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0087, Acc: 97.75%, F1: 0.9776
#   Learning Rate (group0): 7.91e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 17/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:58<00:00,  3.98s/it, loss=0.0072, acc=98.95%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.42s/it, loss=0.0169, acc=97.19%]
# Results:
#   Train - Loss: 0.0072, Acc: 98.95%, F1: 0.9895
#   Val   - Loss: 0.0169, Acc: 97.19%, F1: 0.9720
#   Learning Rate (group0): 7.67e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 18/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:59<00:00,  4.00s/it, loss=0.0236, acc=97.19%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.44s/it, loss=0.0103, acc=98.60%]
# Results:
#   Train - Loss: 0.0236, Acc: 97.19%, F1: 0.9720
#   Val   - Loss: 0.0103, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 7.42e-06
#   💾 Best model saved! (Val Acc: 98.60%)
#   ✓ New best score: 98.5955
#
# Fold 4 - Epoch 19/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:01<00:00,  4.02s/it, loss=0.0070, acc=99.16%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.44s/it, loss=0.0086, acc=98.88%]
# Results:
#   Train - Loss: 0.0070, Acc: 99.16%, F1: 0.9916
#   Val   - Loss: 0.0086, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 7.16e-06
#   💾 Best model saved! (Val Acc: 98.88%)
#   ✓ New best score: 98.8764
#
# Fold 4 - Epoch 20/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:17<00:00,  4.20s/it, loss=0.0073, acc=99.16%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.58s/it, loss=0.0130, acc=98.03%]
# Results:
#   Train - Loss: 0.0073, Acc: 99.16%, F1: 0.9916
#   Val   - Loss: 0.0130, Acc: 98.03%, F1: 0.9804
#   Learning Rate (group0): 6.89e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 21/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:08<00:00,  4.10s/it, loss=0.0036, acc=99.79%]
# Validation: 100%|██████████| 23/23 [00:33<00:00,  1.46s/it, loss=0.0218, acc=97.75%]
# Results:
#   Train - Loss: 0.0036, Acc: 99.79%, F1: 0.9979
#   Val   - Loss: 0.0218, Acc: 97.75%, F1: 0.9774
#   Learning Rate (group0): 6.62e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 22/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:18<00:00,  4.21s/it, loss=0.0045, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.57s/it, loss=0.0328, acc=97.47%]
# Results:
#   Train - Loss: 0.0045, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0328, Acc: 97.47%, F1: 0.9746
#   Learning Rate (group0): 6.34e-06
#   No improvement. Patience: 3/10
#
# Fold 4 - Epoch 23/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:21<00:00,  4.24s/it, loss=0.0067, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:37<00:00,  1.61s/it, loss=0.0102, acc=99.44%]
# Results:
#   Train - Loss: 0.0067, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0102, Acc: 99.44%, F1: 0.9944
#   Learning Rate (group0): 6.06e-06
#   💾 Best model saved! (Val Acc: 99.44%)
#   ✓ New best score: 99.4382
#
# Fold 4 - Epoch 24/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:56<00:00,  4.63s/it, loss=0.0043, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.56s/it, loss=0.0084, acc=98.60%]
# Results:
#   Train - Loss: 0.0043, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0084, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 5.78e-06
#   No improvement. Patience: 1/10
#
# Fold 4 - Epoch 25/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:07<00:00,  4.09s/it, loss=0.0028, acc=99.72%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.42s/it, loss=0.0146, acc=98.60%]
# Results:
#   Train - Loss: 0.0028, Acc: 99.72%, F1: 0.9972
#   Val   - Loss: 0.0146, Acc: 98.60%, F1: 0.9859
#   Learning Rate (group0): 5.50e-06
#   No improvement. Patience: 2/10
#
# Fold 4 - Epoch 26/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:00<00:00,  4.00s/it, loss=0.0067, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.43s/it, loss=0.0154, acc=97.75%]
# Results:
#   Train - Loss: 0.0067, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0154, Acc: 97.75%, F1: 0.9775
#   Learning Rate (group0): 5.22e-06
#   No improvement. Patience: 3/10
#
# Fold 4 - Epoch 27/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:13<00:00,  4.15s/it, loss=0.0107, acc=98.32%]
# Validation: 100%|██████████| 23/23 [00:40<00:00,  1.75s/it, loss=0.0200, acc=98.03%]
# Results:
#   Train - Loss: 0.0107, Acc: 98.32%, F1: 0.9832
#   Val   - Loss: 0.0200, Acc: 98.03%, F1: 0.9804
#   Learning Rate (group0): 4.94e-06
#   No improvement. Patience: 4/10
#
# Fold 4 - Epoch 28/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:07<00:00,  4.75s/it, loss=0.0132, acc=98.67%]
# Validation: 100%|██████████| 23/23 [00:40<00:00,  1.77s/it, loss=0.0131, acc=98.60%]
# Results:
#   Train - Loss: 0.0132, Acc: 98.67%, F1: 0.9867
#   Val   - Loss: 0.0131, Acc: 98.60%, F1: 0.9860
#   Learning Rate (group0): 4.66e-06
#   No improvement. Patience: 5/10
#
# Fold 4 - Epoch 29/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:13<00:00,  4.81s/it, loss=0.0045, acc=99.37%]
# Validation: 100%|██████████| 23/23 [00:40<00:00,  1.75s/it, loss=0.0139, acc=98.31%]
# Results:
#   Train - Loss: 0.0045, Acc: 99.37%, F1: 0.9937
#   Val   - Loss: 0.0139, Acc: 98.31%, F1: 0.9832
#   Learning Rate (group0): 4.38e-06
#   No improvement. Patience: 6/10
#
# Fold 4 - Epoch 30/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [07:01<00:00,  4.69s/it, loss=0.0065, acc=99.23%]
# Validation: 100%|██████████| 23/23 [00:44<00:00,  1.92s/it, loss=0.0157, acc=97.75%]
# Results:
#   Train - Loss: 0.0065, Acc: 99.23%, F1: 0.9923
# ...
# Training: 100%|██████████| 90/90 [06:45<00:00,  4.50s/it, loss=0.0040, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.35s/it, loss=0.0161, acc=97.47%]
# Results:
#   Train - Loss: 0.0040, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0161, Acc: 97.47%, F1: 0.9748
#   Learning Rate (group0): 3.84e-06
#   No improvement. Patience: 8/10
#
# Fold 4 - Epoch 32/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:18<00:00,  3.54s/it, loss=0.0037, acc=99.58%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.36s/it, loss=0.0210, acc=98.31%]
# Results:
#   Train - Loss: 0.0037, Acc: 99.58%, F1: 0.9958
#   Val   - Loss: 0.0210, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 3.58e-06
#   No improvement. Patience: 9/10
#
# Fold 4 - Epoch 33/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0012, acc=99.86%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0185, acc=98.88%]
# Results:
#   Train - Loss: 0.0012, Acc: 99.86%, F1: 0.9986
#   Val   - Loss: 0.0185, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 3.33e-06
#   No improvement. Patience: 10/10
#
# ⚠️ Early stopping triggered!
#    Best score: 99.4382 at epoch 22
#
# ⚠️ Early stopping at epoch 33
#
# 📊 EVALUATING FOLD 4
# ======================================================================
# Validation: 100%|██████████| 23/23 [00:26<00:00,  1.16s/it, loss=0.0102, acc=99.44%]
# 📈 Fold 4 Validation Results:
#   Accuracy:         99.44%
#   Precision:        0.9945
#   Recall:           0.9944
#   F1 Score:         0.9944
#   Sensitivity (Normal):   0.9846
#   Sensitivity (Abnormal): 1.0000
#   Specificity (Normal):   1.0000
#   Specificity (Abnormal): 0.9912
#   Avg Sensitivity:  0.9923
#   Avg Specificity:  0.9956
# ✓ Confusion matrix saved
#
# ======================================================================
# FOLD 5/5
# ======================================================================
#
# 📊 Fold 5 split:
#   Train:      1426 (80.0% of k-fold data)
#   Validation: 356 (20.0% of k-fold data)
#
# 🤖 Creating model for Fold 5...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold 5 - Epoch 1/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.49s/it, loss=0.1060, acc=80.43%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.40s/it, loss=0.0591, acc=91.29%]
# Results:
#   Train - Loss: 0.1060, Acc: 80.43%, F1: 0.8068
#   Val   - Loss: 0.0591, Acc: 91.29%, F1: 0.9116
#   Learning Rate (group0): 9.99e-06
#   💾 Best model saved! (Val Acc: 91.29%)
#   ✓ Initial best score: 91.2921
#
# Fold 5 - Epoch 2/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:16<00:00,  3.52s/it, loss=0.0658, acc=91.23%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0569, acc=93.82%]
# Results:
#   Train - Loss: 0.0658, Acc: 91.23%, F1: 0.9129
#   Val   - Loss: 0.0569, Acc: 93.82%, F1: 0.9373
#   Learning Rate (group0): 9.96e-06
#   💾 Best model saved! (Val Acc: 93.82%)
#   ✓ New best score: 93.8202
#
# Fold 5 - Epoch 3/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:18<00:00,  3.54s/it, loss=0.0482, acc=93.34%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.40s/it, loss=0.0332, acc=97.19%]
# Results:
#   Train - Loss: 0.0482, Acc: 93.34%, F1: 0.9337
#   Val   - Loss: 0.0332, Acc: 97.19%, F1: 0.9716
#   Learning Rate (group0): 9.92e-06
#   💾 Best model saved! (Val Acc: 97.19%)
#   ✓ New best score: 97.1910
#
# Fold 5 - Epoch 4/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:18<00:00,  3.54s/it, loss=0.0467, acc=93.13%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0241, acc=95.79%]
# Results:
#   Train - Loss: 0.0467, Acc: 93.13%, F1: 0.9317
#   Val   - Loss: 0.0241, Acc: 95.79%, F1: 0.9583
#   Learning Rate (group0): 9.86e-06
#   No improvement. Patience: 1/10
#
# Fold 5 - Epoch 5/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:01<00:00,  3.35s/it, loss=0.0284, acc=96.70%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.35s/it, loss=0.2730, acc=72.47%]
# Results:
#   Train - Loss: 0.0284, Acc: 96.70%, F1: 0.9671
#   Val   - Loss: 0.2730, Acc: 72.47%, F1: 0.7256
#   Learning Rate (group0): 9.78e-06
#   No improvement. Patience: 2/10
#
# Fold 5 - Epoch 6/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [04:58<00:00,  3.31s/it, loss=0.0332, acc=95.37%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.32s/it, loss=0.0250, acc=95.79%]
# Results:
#   Train - Loss: 0.0332, Acc: 95.37%, F1: 0.9540
#   Val   - Loss: 0.0250, Acc: 95.79%, F1: 0.9582
#   Learning Rate (group0): 9.68e-06
#   No improvement. Patience: 3/10
#
# Fold 5 - Epoch 7/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:14<00:00,  3.49s/it, loss=0.0282, acc=96.14%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0260, acc=98.03%]
# Results:
#   Train - Loss: 0.0282, Acc: 96.14%, F1: 0.9615
#   Val   - Loss: 0.0260, Acc: 98.03%, F1: 0.9803
#   Learning Rate (group0): 9.57e-06
#   💾 Best model saved! (Val Acc: 98.03%)
#   ✓ New best score: 98.0337
#
# Fold 5 - Epoch 8/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:14<00:00,  3.50s/it, loss=0.0211, acc=97.05%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.36s/it, loss=0.0174, acc=98.31%]
# Results:
#   Train - Loss: 0.0211, Acc: 97.05%, F1: 0.9706
#   Val   - Loss: 0.0174, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 9.44e-06
#   💾 Best model saved! (Val Acc: 98.31%)
#   ✓ New best score: 98.3146
#
# Fold 5 - Epoch 9/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:14<00:00,  3.49s/it, loss=0.0198, acc=97.05%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0096, acc=98.31%]
# Results:
#   Train - Loss: 0.0198, Acc: 97.05%, F1: 0.9706
#   Val   - Loss: 0.0096, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 9.30e-06
#   No improvement. Patience: 1/10
#
# Fold 5 - Epoch 10/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0185, acc=97.41%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0198, acc=98.03%]
# Results:
#   Train - Loss: 0.0185, Acc: 97.41%, F1: 0.9741
#   Val   - Loss: 0.0198, Acc: 98.03%, F1: 0.9802
#   Learning Rate (group0): 9.14e-06
#   No improvement. Patience: 2/10
#
# Fold 5 - Epoch 11/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:12<00:00,  3.48s/it, loss=0.0130, acc=98.25%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0252, acc=98.03%]
# Results:
#   Train - Loss: 0.0130, Acc: 98.25%, F1: 0.9825
#   Val   - Loss: 0.0252, Acc: 98.03%, F1: 0.9802
#   Learning Rate (group0): 8.97e-06
#   No improvement. Patience: 3/10
#
# Fold 5 - Epoch 12/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:12<00:00,  3.47s/it, loss=0.0174, acc=97.90%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0389, acc=97.47%]
# Results:
#   Train - Loss: 0.0174, Acc: 97.90%, F1: 0.9790
#   Val   - Loss: 0.0389, Acc: 97.47%, F1: 0.9746
#   Learning Rate (group0): 8.78e-06
#   No improvement. Patience: 4/10
#
# Fold 5 - Epoch 13/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:07<00:00,  3.41s/it, loss=0.0178, acc=98.74%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.36s/it, loss=0.0126, acc=97.75%]
# Results:
#   Train - Loss: 0.0178, Acc: 98.74%, F1: 0.9874
#   Val   - Loss: 0.0126, Acc: 97.75%, F1: 0.9776
#   Learning Rate (group0): 8.58e-06
#   No improvement. Patience: 5/10
#
# Fold 5 - Epoch 14/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:09<00:00,  3.43s/it, loss=0.0238, acc=96.56%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.34s/it, loss=0.0205, acc=98.31%]
# Results:
#   Train - Loss: 0.0238, Acc: 96.56%, F1: 0.9658
#   Val   - Loss: 0.0205, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 8.37e-06
#   No improvement. Patience: 6/10
#
# Fold 5 - Epoch 15/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:05<00:00,  3.40s/it, loss=0.0083, acc=98.88%]
# Validation: 100%|██████████| 23/23 [00:29<00:00,  1.29s/it, loss=0.0141, acc=98.88%]
# Results:
#   Train - Loss: 0.0083, Acc: 98.88%, F1: 0.9888
#   Val   - Loss: 0.0141, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 8.15e-06
#   💾 Best model saved! (Val Acc: 98.88%)
#   ✓ New best score: 98.8764
#
# Fold 5 - Epoch 16/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:01<00:00,  3.35s/it, loss=0.0074, acc=98.88%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.34s/it, loss=0.0137, acc=97.75%]
# Results:
#   Train - Loss: 0.0074, Acc: 98.88%, F1: 0.9888
#   Val   - Loss: 0.0137, Acc: 97.75%, F1: 0.9775
#   Learning Rate (group0): 7.91e-06
#   No improvement. Patience: 1/10
#
# Fold 5 - Epoch 17/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:16<00:00,  3.52s/it, loss=0.0044, acc=99.23%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0186, acc=98.88%]
# Results:
#   Train - Loss: 0.0044, Acc: 99.23%, F1: 0.9923
#   Val   - Loss: 0.0186, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 7.67e-06
#   No improvement. Patience: 2/10
#
# Fold 5 - Epoch 18/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0055, acc=99.16%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0526, acc=97.47%]
# Results:
#   Train - Loss: 0.0055, Acc: 99.16%, F1: 0.9916
#   Val   - Loss: 0.0526, Acc: 97.47%, F1: 0.9745
#   Learning Rate (group0): 7.42e-06
#   No improvement. Patience: 3/10
#
# Fold 5 - Epoch 19/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0099, acc=98.88%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.37s/it, loss=0.0131, acc=98.31%]
# Results:
#   Train - Loss: 0.0099, Acc: 98.88%, F1: 0.9888
#   Val   - Loss: 0.0131, Acc: 98.31%, F1: 0.9832
#   Learning Rate (group0): 7.16e-06
#   No improvement. Patience: 4/10
#
# Fold 5 - Epoch 20/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:11<00:00,  3.46s/it, loss=0.0041, acc=99.44%]
# Validation: 100%|██████████| 23/23 [00:32<00:00,  1.43s/it, loss=0.0314, acc=98.03%]
# Results:
#   Train - Loss: 0.0041, Acc: 99.44%, F1: 0.9944
#   Val   - Loss: 0.0314, Acc: 98.03%, F1: 0.9802
#   Learning Rate (group0): 6.89e-06
#   No improvement. Patience: 5/10
#
# Fold 5 - Epoch 21/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:14<00:00,  3.49s/it, loss=0.0103, acc=98.39%]
# Validation: 100%|██████████| 23/23 [00:30<00:00,  1.35s/it, loss=0.0397, acc=98.03%]
# Results:
#   Train - Loss: 0.0103, Acc: 98.39%, F1: 0.9839
#   Val   - Loss: 0.0397, Acc: 98.03%, F1: 0.9803
#   Learning Rate (group0): 6.62e-06
#   No improvement. Patience: 6/10
#
# Fold 5 - Epoch 22/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:13<00:00,  3.48s/it, loss=0.0086, acc=98.95%]
# Validation: 100%|██████████| 23/23 [00:31<00:00,  1.38s/it, loss=0.0494, acc=98.31%]
# Results:
#   Train - Loss: 0.0086, Acc: 98.95%, F1: 0.9895
#   Val   - Loss: 0.0494, Acc: 98.31%, F1: 0.9831
#   Learning Rate (group0): 6.34e-06
#   No improvement. Patience: 7/10
#
# Fold 5 - Epoch 23/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [05:18<00:00,  3.54s/it, loss=0.0043, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.56s/it, loss=0.0265, acc=98.88%]
# Results:
#   Train - Loss: 0.0043, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0265, Acc: 98.88%, F1: 0.9887
#   Learning Rate (group0): 6.06e-06
#   No improvement. Patience: 8/10
#
# Fold 5 - Epoch 24/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:43<00:00,  4.48s/it, loss=0.0065, acc=99.51%]
# Validation: 100%|██████████| 23/23 [00:36<00:00,  1.57s/it, loss=0.0254, acc=98.88%]
# Results:
#   Train - Loss: 0.0065, Acc: 99.51%, F1: 0.9951
#   Val   - Loss: 0.0254, Acc: 98.88%, F1: 0.9888
#   Learning Rate (group0): 5.78e-06
#   No improvement. Patience: 9/10
#
# Fold 5 - Epoch 25/50
# ----------------------------------------------------------------------
# Training: 100%|██████████| 90/90 [06:37<00:00,  4.42s/it, loss=0.0321, acc=96.63%]
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.53s/it, loss=0.0142, acc=97.75%]
# Results:
#   Train - Loss: 0.0321, Acc: 96.63%, F1: 0.9665
#   Val   - Loss: 0.0142, Acc: 97.75%, F1: 0.9776
#   Learning Rate (group0): 5.50e-06
#   No improvement. Patience: 10/10
#
# ⚠️ Early stopping triggered!
#    Best score: 98.8764 at epoch 14
#
# ⚠️ Early stopping at epoch 25
#
# 📊 EVALUATING FOLD 5
# ======================================================================
# Validation: 100%|██████████| 23/23 [00:35<00:00,  1.55s/it, loss=0.0141, acc=98.88%]
# 📈 Fold 5 Validation Results:
#   Accuracy:         98.88%
#   Precision:        0.9890
#   Recall:           0.9888
#   F1 Score:         0.9887
#   Sensitivity (Normal):   1.0000
#   Sensitivity (Abnormal): 0.9828
#   Specificity (Normal):   0.9688
#   Specificity (Abnormal): 1.0000
#   Avg Sensitivity:  0.9914
#   Avg Specificity:  0.9844
# ✓ Confusion matrix saved
#
# ======================================================================
# 📊 K-FOLD CROSS-VALIDATION SUMMARY
# ======================================================================
#
# 📈 Cross-Validation Results (5 folds):
#   Accuracy:     99.16% ± 0.25%
#   Precision:    0.9917 ± 0.0025
#   Recall:       0.9916 ± 0.0025
#   F1 Score:     0.9916 ± 0.0025
#   Sensitivity:  0.9911 ± 0.0031
#   Specificity:  0.9907 ± 0.0037
#
# 🏆 Best Fold: 2 (Val Acc: 99.44%)
#
# ======================================================================
# 🧪 EVALUATING BEST MODEL ON HOLDOUT TEST SET
# ======================================================================
#
# 📊 Loading best model from Fold 2...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Validation: 100%|██████████| 13/13 [00:24<00:00,  1.85s/it, loss=0.0571, acc=95.48%]
# 📈 Test Set Results (Best Model from Fold 2):
#   Accuracy:         95.48%
#   Precision:        0.9553
#   Recall:           0.9548
#   F1 Score:         0.9544
#   Sensitivity (Normal):   0.9697
#   Sensitivity (Abnormal): 0.9474
#   Specificity (Normal):   0.9014
#   Specificity (Abnormal): 0.9844
#   Avg Sensitivity:  0.9585
#   Avg Specificity:  0.9429
#
# ✓ Test confusion matrix saved
# ✓ Results saved to CSV
#
# ======================================================================
# ✅ TRAINING COMPLETE
# ======================================================================
#
# 📊 Final Summary:
#   Dataset: ERBMAHE (Abnormal vs Normal)
#   Model: Baseline 4 — ViT + CNN (No CBAM, No Quantum)
#   Strategy: Method 2 K-Fold with 10% Test Set
#   K-Fold CV Accuracy: 99.16% ± 0.25%
#   Test Set Accuracy:  95.48%
#   Test Set F1 Score:  0.9544
#
# ======================================================================
